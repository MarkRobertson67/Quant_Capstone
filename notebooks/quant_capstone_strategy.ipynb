# %%
import krakenex
import pandas as pd
import matplotlib.pyplot as plt

api = krakenex.API()

# Get OHLC data (interval = 1440 = daily)
resp = api.query_public('OHLC', data={
    'pair': 'XXBTZUSD',
    'interval': 1440
})

# Parse the result
ohlc_data = resp['result']['XXBTZUSD']
df = pd.DataFrame(ohlc_data, columns=[
    'time', 'open', 'high', 'low', 'close', 'vwap', 'volume', 'count'
])
df['time'] = pd.to_datetime(df['time'], unit='s')
df.set_index('time', inplace=True)
df = df.astype(float)

# Add 20-day SMA
df['SMA20'] = df['close'].rolling(window=20).mean()

# Plot
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['close'], label='Close')
plt.plot(df.index, df['SMA20'], label='20-day SMA')
plt.title('BTC/USD with 20-Day SMA (Kraken)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import krakenex
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'krakenex'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Mark\anaconda3\envs\capstone\python.exe
